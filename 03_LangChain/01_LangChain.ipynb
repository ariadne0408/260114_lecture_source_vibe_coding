# %% [markdown]
# # LangChain 소개

# %% [markdown]
# ## 1. LangChain이란?
#
#  - LangChain은 LLM(거대 언어 모델)을 활용하여 실제 애플리케이션을 쉽고 강력하게 구축할 수 있도록 도와주는 프레임워크입니다.
#  - 단순히 모델을 호출하는 것을 넘어, 데이터 연결, 에이전트 생성, 체인 구성 등 LLM 애플리케이션에 필요한 다양한 기능을 모듈화하여 제공합니다.
# ### 핵심 정의
# - LLM 기반 애플리케이션의 전체 라이프사이클을 단순화
# - 개발부터 배포까지 종합적인 솔루션 제공
# - 다양한 LLM 제공업체와의 표준화된 인터페이스 구현
#
# #### 우리가 주로 사용할 LangChain 모듈들
# 1. PromptTemplate
# 2. OutputParser
# 3. Model
# 4. DocumentLoader
# 5. TextSpliter
# 6. Embedding
# 7. VectorStore

# %% [markdown]
# ### 기본 사용 예제

# %% [markdown]
# #### 1. API 키 설정

# %%
import os
from dotenv import load_dotenv

# .env 파일에서 환경변수 로드
load_dotenv()

# OpenAI API 환경변수 값 확인
openai_api_key = os.getenv('OPENAI_API_KEY')
print(f"OPENAI_API_KEY가 설정되어 있나요?: {openai_api_key[:10]}...")
# Out:
# OPENAI_API_KEY가 설정되어 있나요?: sk-proj-7l...

# %% [markdown]
# #### 2. 채팅 모델 초기화

# %%
# %pip install langchain-openai langchain openai dotenv
# Out:
# Requirement already satisfied: langchain-openai in c:\programdata\miniforge3\envs\bear\lib\site-packages (1.1.7)
# Requirement already satisfied: langchain in c:\programdata\miniforge3\envs\bear\lib\site-packages (1.2.4)
# Requirement already satisfied: openai in c:\programdata\miniforge3\envs\bear\lib\site-packages (2.15.0)
# Requirement already satisfied: dotenv in c:\programdata\miniforge3\envs\bear\lib\site-packages (0.9.9)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.6 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from langchain-openai) (1.2.7)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from openai) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in c:\programdata\miniforge3\envs\bear\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in c:\programdata\miniforge3\envs\bear\lib\site-packages (from httpx<1,>=0.23.0->openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\programdata\miniforge3\envs\bear\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain-openai) (0.6.4)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain-openai) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain-openai) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain-openai) (0.13.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.6->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain-openai) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain-openai) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain-openai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.1.15)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from langchain) (1.0.6)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.6)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.3)
# Requirement already satisfied: xxhash>=3.5.0 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.1)
# Requirement already satisfied: python-dotenv in c:\programdata\miniforge3\envs\bear\lib\site-packages (from dotenv) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain-openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\miniforge3\envs\bear\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain-openai) (2.6.3)
# Requirement already satisfied: colorama in c:\programdata\miniforge3\envs\bear\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.chat_models import init_chat_model

# model provider : 모델 제공사
# temperature : 창의성 정도
llm = init_chat_model("gpt-4o-mini", model_provider="openai", temperature=0.5)

print("모델이 성공적으로 초기화되었습니다!")
# Out:
# 모델이 성공적으로 초기화되었습니다!

# %% [markdown]
# #### 3.LLM 호출

# %%
# 간단한 메시지 전송
# invoke : 실행명령어
response = llm.invoke("안녕하세요! LangChain에 대해 간단히 설명해주세요.")

print("AI 응답:")
print(response.content)
# Out:
# AI 응답:
# 안녕하세요! LangChain은 다양한 자연어 처리(NLP) 작업을 수행할 수 있도록 도와주는 프레임워크입니다. 주로 대화형 AI 애플리케이션을 구축하는 데 사용되며, 특히 언어 모델과의 상호작용을 간편하게 만들어줍니다.
#
# LangChain의 주요 기능은 다음과 같습니다:
#
# 1. **체인**: 여러 NLP 작업을 연결하여 복잡한 프로세스를 구성할 수 있습니다. 예를 들어, 입력을 받아서 처리하고, 그 결과를 다른 작업에 전달하는 방식으로 체인을 만들 수 있습니다.
#
# 2. **프롬프트 템플릿**: 사용자가 원하는 형식으로 언어 모델에 질문을 던질 수 있도록 프롬프트를 쉽게 구성할 수 있는 도구를 제공합니다.
#
# 3. **데이터 연결**: 외부 데이터 소스와의 통합이 용이하여, 다양한 형식의 데이터를 모델에 활용할 수 있습니다.
#
# 4. **에이전트**: 사용자의 요청에 따라 동적으로 작업을 수행할 수 있는 에이전트를 구축할 수 있습니다.
#
# 이러한 기능들을 통해 LangChain은 대화형 AI 시스템을 보다 효율적으로 개발하고 운영할 수 있도록 지원합니다.

# %%
print(response)
# Out:
# content='안녕하세요! LangChain은 다양한 자연어 처리(NLP) 작업을 수행할 수 있도록 도와주는 프레임워크입니다. 주로 대화형 AI 애플리케이션을 구축하는 데 사용되며, 특히 언어 모델과의 상호작용을 간편하게 만들어줍니다.\n\nLangChain의 주요 기능은 다음과 같습니다:\n\n1. **체인**: 여러 NLP 작업을 연결하여 복잡한 프로세스를 구성할 수 있습니다. 예를 들어, 입력을 받아서 처리하고, 그 결과를 다른 작업에 전달하는 방식으로 체인을 만들 수 있습니다.\n\n2. **프롬프트 템플릿**: 사용자가 원하는 형식으로 언어 모델에 질문을 던질 수 있도록 프롬프트를 쉽게 구성할 수 있는 도구를 제공합니다.\n\n3. **데이터 연결**: 외부 데이터 소스와의 통합이 용이하여, 다양한 형식의 데이터를 모델에 활용할 수 있습니다.\n\n4. **에이전트**: 사용자의 요청에 따라 동적으로 작업을 수행할 수 있는 에이전트를 구축할 수 있습니다.\n\n이러한 기능들을 통해 LangChain은 대화형 AI 시스템을 보다 효율적으로 개발하고 운영할 수 있도록 지원합니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 264, 'prompt_tokens': 20, 'total_tokens': 284, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CyXUcsO2SXUqNIKLWVSVw720A0PcA', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019bc576-e523-7f50-9b27-5f9b226e9ecd-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 20, 'output_tokens': 264, 'total_tokens': 284, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %% [markdown]
# #### AIMessage
# - LangChain에서 LLM 호출 시 `AIMessage` 객체가 반환됩니다.
# - LangChain 프레임워크에서 AI 언어 모델이 생성한 메시지를 나타내는 데이터 구조(클래스)입니다.
# ---
# **주요 구성 요소**
# 1. content
# - 모델이 실제로 생성한 답변 텍스트
# 2. additional_kwargs
# - 부가 옵션 (예: 거부 여부 `refusal`)
# 3. response_metadata
# - 모델 관련 상세 정보
#   - 사용된 모델 이름 (`model_name`)
#   - 토큰 사용량 (`prompt_tokens`, `completion_tokens`, `total_tokens`)
#   - 응답 종료 이유 (`finish_reason`)
# 4. usage_metadata
# - LangChain이 정리한 토큰 사용량 요약

# %%
print(response.content)
# Out:
# 안녕하세요! LangChain은 다양한 자연어 처리(NLP) 작업을 수행할 수 있도록 도와주는 프레임워크입니다. 주로 대화형 AI 애플리케이션을 구축하는 데 사용되며, 특히 언어 모델과의 상호작용을 간편하게 만들어줍니다.
#
# LangChain의 주요 기능은 다음과 같습니다:
#
# 1. **체인**: 여러 NLP 작업을 연결하여 복잡한 프로세스를 구성할 수 있습니다. 예를 들어, 입력을 받아서 처리하고, 그 결과를 다른 작업에 전달하는 방식으로 체인을 만들 수 있습니다.
#
# 2. **프롬프트 템플릿**: 사용자가 원하는 형식으로 언어 모델에 질문을 던질 수 있도록 프롬프트를 쉽게 구성할 수 있는 도구를 제공합니다.
#
# 3. **데이터 연결**: 외부 데이터 소스와의 통합이 용이하여, 다양한 형식의 데이터를 모델에 활용할 수 있습니다.
#
# 4. **에이전트**: 사용자의 요청에 따라 동적으로 작업을 수행할 수 있는 에이전트를 구축할 수 있습니다.
#
# 이러한 기능들을 통해 LangChain은 대화형 AI 시스템을 보다 효율적으로 개발하고 운영할 수 있도록 지원합니다.

# %%
print(response.response_metadata)

# %% [markdown]
# ## 2.LCEL (Langchain Chain Expression Language)
# **LCEL이란?**
# - Langchain에서 프롬프트, 체인, LLM 호출 등 다양한 구성요소를 함수형으로 조합할 수 있음.
# - 파이프라인처럼 여러 단계를 연결하여 복잡한 워크플로우를 간결하게 체인형태로 구현할 수 있다.
# - 각 단계는 함수(또는 객체)로 표현되며, 입력과 출력을 연결 가능하다.
# - 예시: (프롬프트 → LLM → 후처리) 과정을 한 줄로 연결하여 작성 가능합니다
# - `chain = prompt | model | output`

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate.from_template("{input}가 무엇인가요?")

# %%
# chain 만들기
chain = prompt | llm

# %%
# 유저 입력
input = "cafe"

# 응답 출력
response = chain.invoke(input)
print(response.content)
# Out:
# "카페(café)"는 일반적으로 커피와 다양한 음료, 그리고 간단한 음식을 제공하는 장소를 의미합니다. 카페는 보통 편안한 분위기에서 친구와 대화를 나누거나 혼자서 책을 읽거나 작업을 하는 공간으로 인식됩니다. 커피 외에도 차, 디저트, 샌드위치, 샐러드 등 다양한 메뉴를 제공하는 경우가 많습니다. 카페는 도시의 거리나 쇼핑몰, 공원 등 다양한 장소에 위치해 있으며, 일부 카페는 특정 테마나 스타일을 가지고 있어 독특한 경험을 제공합니다.

# %% [markdown]
# ### 공식 리소스
# - **공식 문서**: [python.langchain.com](https://python.langchain.com)
